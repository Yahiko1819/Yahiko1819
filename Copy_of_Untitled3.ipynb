# %% [markdown]
# <a href="https://colab.research.google.com/github/Yahiko1819/Yahiko1819/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pandas as pd
import pandas as np

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()

# %%
df1['viewers'] = ["Sushmita", "Adam", "Benny", "Anurag","anna"]
df2['users'] = ["Adam", "Anurag", "Benny", "Sushmita", "anna"]
df3['Main'] = ["Core", "fighter", "mage", "ADC", "Support"]
df4['Stats'] = ["Core", "fighter", "mage", "ADC", "Support"]

# %%
df1 = df1.assign(views = [5,10,20,30,10])
df2 = df2.assign(cost = [20,15, 18, 10, 30])
df3 = df3.assign(Stats = [10.1,8.6,5.6,2.1,11.0])
df4 = df4.assign(Final = [11.2,8.4,5.6,2.1,11.0])

# %%
df1.head()
# Out:
#     viewers  views
# 0  Sushmita      5
# 1      Adam     10
# 2     Benny     20
# 3    Anurag     30
# 4      anna     10

# %%
df2.head()
# Out:
#       users  cost
# 0      Adam    20
# 1    Anurag    15
# 2     Benny    18
# 3  Sushmita    10
# 4      anna    30

# %%
df = df1.merge(df2, left_on="viewers", right_on="users", how="left")
df.head()
# Out:
#     viewers  views     users  cost
# 0  Sushmita      5  Sushmita    10
# 1      Adam     10      Adam    20
# 2     Benny     20     Benny    18
# 3    Anurag     30    Anurag    15
# 4      anna     10      anna    30

# %%
df=df.fillna(df.mean())
# Out:
# <ipython-input-128-6f8c6f28e805>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df.fillna(df.mean())

# %%
df['Gender'] = ["Female", "Male", "Male", "Female","Female"]

# %%
df
# Out:
#     viewers  views     users  cost  Gender
# 0  Sushmita      5  Sushmita    10  Female
# 1      Adam     10      Adam    20    Male
# 2     Benny     20     Benny    18    Male
# 3    Anurag     30    Anurag    15  Female
# 4      anna     10      anna    30  Female
